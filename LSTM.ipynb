# %%
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences, to_categorical
from sklearn.preprocessing import LabelEncoder
from keras import Sequential, regularizers
from keras.layers import LSTM, Embedding, Dropout, Dense
from keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, confusion_matrix
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from apiclient import discovery
tokenizer = None
model = None
FILEPATH = 'Dataset Twitter Fix - Indonesian Sentiment Twitter Dataset Labeled.csv'
SLANGPATH = 'colloquial-indonesian-lexicon.csv'
slang_dictionary = None
sentiment_amount = 3
sentiments = ["neutral", "positive", "negative"]

# %%
# get dataset + preprocessing teks
def get_dataset():
    dataset = pd.read_csv(FILEPATH)

    all_data = []
    dataset = dataset[dataset['sentimen'].isin([0, 1, 2])]
    smallest = list(dataset['sentimen']).count(0)
    for i in range(sentiment_amount):
        smallest = min(smallest, list(dataset['sentimen']).count(i))
    for i in range(sentiment_amount):
        data = dataset[dataset['sentimen'] == i]
        pos = np.random.choice(data.index, len(data) - smallest, replace=False)
        data = data.drop(pos)
        all_data.append(data)

    dataset = pd.concat(all_data)

    for index, data in dataset.iterrows():
        text = data['Tweet']
        text = str(text).lower()
        word_list = word_tokenize(text)
        temp = []
        if slang_dictionary == None:
            initialize_slang_dictionary()
        for word in word_list:
            if slang_dictionary.get(word):
                temp.append(slang_dictionary[word])
            else:
                temp.append(word)
        word_list = temp
        id_stopwords = stopwords.words('indonesian')
        word_list = [word for word in word_list if word not in id_stopwords]
        factory = StemmerFactory()
        stemmer = factory.create_stemmer()
        word_list = [stemmer.stem(word) for word in word_list]
        text = ' '.join(word_list)
        dataset.at[index, 'Tweet'] = text

    dataset = dataset.sample(frac = 1)

    return dataset

def initialize_slang_dictionary():
    global slang_dictionary
    slang_dictionary = {}
    dataset = pd.read_csv(SLANGPATH)
    for _, data in dataset.iterrows():
        key = data['slang']
        value = data['formal']
        slang_dictionary[key] = value

# training model
def train_model():
    dataset = get_dataset()
    x, y = preprocess_data(dataset['Tweet'], dataset['sentimen'])
    global model
    initialize_model()
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    early_stopping = EarlyStopping(monitor='val_loss', min_delta=0, patience=3, verbose=1, mode='auto')
    x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8)
    model.fit(x_train, y_train, epochs=10, batch_size=32, validation_data=(x_test, y_test), callbacks=[early_stopping])
    score = model.evaluate(x_test, y_test, verbose = 1)
    y_pred = model.predict(x_test)
    y_pred = np.argmax(y_pred, axis=1)
    y_test_argmax = np.argmax(y_test, axis=1)

    print('Score: ', score)
    print('Accuracy: ', accuracy_score(y_test_argmax, y_pred))
    print('Precision:', precision_score(y_test_argmax, y_pred, average='weighted'))
    print('Recall:', recall_score(y_test_argmax, y_pred, average='weighted'))
    print('F1 score:', f1_score(y_test_argmax, y_pred, average='weighted'))
    print('Confusion Matrix: \n', confusion_matrix(y_test_argmax, y_pred))
    model.save('LSTM.keras')

def preprocess_data(text_list, sentiments):
    global tokenizer
    if tokenizer == None:
        initialize_tokenizer()

    sequences = tokenizer.texts_to_sequences(text_list)

    x = pad_sequences(sequences)

    le = LabelEncoder()
    y = le.fit_transform(sentiments)
    y = to_categorical(y)

    return x, y

def initialize_tokenizer():
    dataset = get_dataset()
    global tokenizer
    tokenizer = Tokenizer(num_words=4000)
    tokenizer.fit_on_texts(dataset['Tweet'])

def initialize_model():
    global model
    word_count = get_word_count()
    model = Sequential([
        Embedding(input_dim=word_count + 1, output_dim=200),
        LSTM(128, return_sequences=True),
        Dropout(0.5),
        LSTM(128),
        Dense(64, activation='relu', 
            kernel_regularizer=regularizers.l2(0.01), 
            activity_regularizer=regularizers.l1(0.01)),
        Dense(sentiment_amount, activation='softmax')
    ])

def get_word_count():
    global tokenizer
    if tokenizer == None:
        initialize_tokenizer()
    return len(tokenizer.word_index)

# testing model
def load_model():
    global model
    if model == None:
        initialize_model()
    model.load_weights('LSTM.keras')

def predict_comment(text):
    global model
    global tokenizer
    if tokenizer == None:
        initialize_tokenizer()
    if model == None:
        initialize_model()
    sequences = tokenizer.texts_to_sequences(text)
    x = pad_sequences(sequences)
    y_pred = model.predict(x)
    y_pred = np.argmax(y_pred, axis=1)

    for index, comment in enumerate(text):
        print(f"{comment}: {sentiments[y_pred[index]]}")

# %%
# Inisialisasi Youtube API
api_key = ''
youtube = discovery.build('youtube', 'v3', developerKey=api_key)

def get_comments(video_id):
    comments = []
    response = youtube.commentThreads().list(
        part = 'snippet',
        videoId = video_id,
        maxResults = 600,     # menyesuaikan jumlah ini
        textFormat = 'plainText'
    ).execute()
    while response:
        for item in response['items']:
            comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
            comments.append(comment)

            if len(comments) >= 10000:     # Batas jumlah komentar
                return comments

        if 'nextPageToken' in response:
            response = youtube.commentThreads().list(
            part = 'snippet',
            videoId = video_id,
            pageToken = response['nextPageToken'],
            maxResults = 100,     # menyesuaikan jumlah ini
            textFormat = 'plainText'
        ).execute()
        else:
            break
    return comments

# %%
train_model()
# Out:
# Epoch 1/10
# 210/210 [==============================] - 65s 281ms/step - loss: 1.2660 - accuracy: 0.4360 - val_loss: 0.9862 - val_accuracy: 0.5447
# Epoch 2/10
# 210/210 [==============================] - 56s 267ms/step - loss: 0.8447 - accuracy: 0.6531 - val_loss: 0.8929 - val_accuracy: 0.6056
# Epoch 3/10
# 210/210 [==============================] - 60s 285ms/step - loss: 0.6636 - accuracy: 0.7551 - val_loss: 0.9327 - val_accuracy: 0.6086
# Epoch 4/10
# 210/210 [==============================] - 62s 296ms/step - loss: 0.5537 - accuracy: 0.8082 - val_loss: 1.0288 - val_accuracy: 0.6026
# Epoch 5/10
# 210/210 [==============================] - 63s 301ms/step - loss: 0.4582 - accuracy: 0.8524 - val_loss: 1.1590 - val_accuracy: 0.5943
# Epoch 5: early stopping
# 53/53 [==============================] - 4s 75ms/step - loss: 1.1590 - accuracy: 0.5943
# 53/53 [==============================] - 5s 69ms/step
# Score:  [1.1589776277542114, 0.5942720770835876]
# Accuracy:  0.594272076372315
# Precision: 0.598995906917254
# Recall: 0.594272076372315
# F1 score: 0.5957466732415336
# Confusion Matrix:
#  [[321 133 100]
#  [173 330  66]
#  [121  87 345]]

# %%
comments = get_comments('RRgLZ66NCmE')
predict_comment(comments)
# Out:
# 313/313 [==============================] - 115s 368ms/step
# TimeStamp Film:
#
# 00:00:00 Opening
# 00:12:35 Peta Suara Sumatera Pilpres 2014 dan 2019
# 00:13:47 Pemecahan Papua menjadi 6 Provinisi
# mampus lu ekwkwkwk: negative
# Film ini adalah konspirasi ,dalam arti memecah belah bangsa: negative
# WKWKWK 02 MENANG: positive
# BACOTTTT YANG BIKIN DIRTY VOTE....... 02 JAYA SEHAT SELALU BAPAK PRABOWO: positive
# 3 Otang Akademisi Konyol Berwawasan KOSONG: neutral
# Film nya gak ngaruh sama pendukung 02 😂: positive
# Oke Terimakasih atas tontonan nya, Sekarang Saya juga ingin menyampaikan sebuah fakta bahwa 02 udah Resmi jadi Winner😁 tas tas tas: neutral
# *1:57:18** · **#Émndhinkk**'s "DIRTY VOTE - Full Movie (OFFICIAL Chanel)"* (-4) *~*
#
# _~ "21/03/24" ~_: neutral
# Ndak cocok kalau ini di sebut film 😂,lebih cocok di sebut teater: positive
# TRIO AMPAS: neutral
# 2 KATA LUCU KAMI NETRAL: positive
# Film tai....sampah...ngak berguna: negative
# Film tai dan ternyata di perankan oleh gelandangan politik: positive
# Nanti kalo 2 putaran 80% , kejang" kalian: positive
# setelah pilpres dan prabowo menang gw baru nnton😂😂😂: positive
# Ada nenek miskin yang memiliki Kartu Keluarga Sejahtera (KKS) dan Terdaftar dalam Data terpadu (DTKS), berada dalam kondisi sosial ekonomi miskin dan rentan tidak mendapat Bansos yang dibagikan langsung oleh Pr3s1den J0k0w1 itu berarti Pa J0k0w1 harus diproses KPK dugaan K0r0ps1? Rakyat harus turun minta Pa J0k0w1 mengundurkan diri dengan hormat dan minta pasl0n 2 didiskualifikasi dan dihukum tidak b0leh ikut pemilu dan pasl0n 01 dan pasl0n 03 men0lak menandatangani hasil pemilu? Ketua KPU harus diperiksa KPK dugaan korupsi dana sirekap dan dugaan tindak pidana KPU karena terjadi kenaikan data masuk dari TPS tetapi jumlah real suara P3 bisa turun? Tidak satu Parpolpun bisa punya uang untuk mengontrol seluruh TPS dan C1 maka dilaporkan P0lr1 dan TN1 ke Kejaksaan dugaan tindak pidana kaitan dengan pemilu dan pembatalan dwifungsi polri dan t41 bisa masuk ke struktural ASN? Kenapa prosentasi kemengan seolah sudah dikunci? Lalu lalu menang 58% kenapa ada 62% minta Hak Angket dugaan kecurangan pilpres? Anomali?Jauh lebih baik semua penyelenggara Pemilu diganti. Dan pemilu diulang. Dan paslon 02 didiskualifikasi. Tidak bisa diabaikan ketika semua kampus dan semua guru besar dan semua tokoh bangsa dan semua budayan yang turun ke jalan untuk demo ditandingi dengan segelintir demo bayaran yang mendukung paslo4 02? DPR harus utuh gelar hak angket daripada semua rakyat turun minta r3volusi r3formasi tahap 2? Demo yang terjadi bukan parpol dan bukan pasl0n dan bukan demo bayaran, tetapi murni rakyat?: positive
# Ada nenek miskin yang memiliki Kartu Keluarga Sejahtera (KKS) dan Terdaftar dalam Data terpadu (DTKS), berada dalam kondisi sosial ekonomi miskin dan rentan tidak mendapat Bansos yang dibagikan langsung oleh Pr3s1den J0k0w1 itu berarti Pa J0k0w1 harus diproses KPK dugaan K0r0ps1? Rakyat harus turun minta Pa J0k0w1 mengundurkan diri dengan hormat dan minta pasl0n 2 didiskualifikasi dan dihukum tidak b0leh ikut pemilu dan pasl0n 01 dan pasl0n 03 men0lak menandatangani hasil pemilu? Ketua KPU harus diperiksa KPK dugaan korupsi dana sirekap dan dugaan tindak pidana KPU karena terjadi kenaikan data masuk dari TPS tetapi jumlah real suara P3 bisa turun? Tidak satu Parpolpun bisa punya uang untuk mengontrol seluruh TPS dan C1 maka dilaporkan P0lr1 dan TN1 ke Kejaksaan dugaan tindak pidana kaitan dengan pemilu dan pembatalan dwifungsi polri dan t41 bisa masuk ke struktural ASN? Kenapa prosentasi kemengan seolah sudah dikunci? Lalu lalu menang 58% kenapa ada 62% minta Hak Angket dugaan kecurangan pilpres? Anomali?Jauh lebih baik semua penyelenggara Pemilu diganti. Dan pemilu diulang. Dan paslon 02 didiskualifikasi. Tidak bisa diabaikan ketika semua kampus dan semua guru besar dan semua tokoh bangsa dan semua budayan yang turun ke jalan untuk demo ditandingi dengan segelintir demo bayaran yang mendukung paslo4 02? DPR harus utuh gelar hak angket daripada semua rakyat turun minta r3volusi r3formasi tahap 2? Demo yang terjadi bukan parpol dan bukan pasl0n dan bukan demo bayaran, tetapi murni rakyat?: positive
# Kasian ngehabisin waktu satu jam buat hal gak guna: neutral
# Biaya pembuatan nya ni,di tanggung sendiri atau orang min, Terus hasilnya ni banyak kah uang nya😅😅 cuma nanya tidak niat apalagi mempermasalahkan: neutral
# dan semua terbukti😮😮😮😮: positive
# prawbowo menang mampus klen: negative
# Terimakasih atas video nya, sehingga membuat saya makin mantap mendukung pak Prabowo dibanding memilih pengkhianat Prabowo dan petugas partai banteng yg petingginya sampai membuat Jokowi sakit hati.
#
# #2024PrabowoGibranSatuPutaran
# #2024PrabowoPutinTrump_ForPeaceWorld: positive
# Up tanpa emotikon: neutral
# Kuceng kuceng: neutral
# buzzer semua isi nya komen terbaru, gue yakin kalian gak ada yg nonton dan cuma kesini hate komen doang. emang susah orang diajak berfikir wkwkkw: positive
# apakah masyarakat indonesia hanyabisadiam ?: positive
# Uda capek2 bikin film masi aja kalah 🤣🤣🤣 bodoh emg pemecah belah bangsa ini 🤣🤣🤣: negative
# Video ini untuk mengkritik siapa sebenar. Agak lain..: negative
# menang #satuputaran #prabowogibran #PresidenRI2024: negative
# Itu sudah pilihat masyarakat untuk pak prabowo: negative
# SUDAH BUAT MOVIE, KALAH.... KASIAN
# GAK BALIK MODAL??: neutral
# Survai yg mana katakan 1 putaran,emang betul  emang semua di kondisikan TSM: neutral
# Udh susah2 bikin film tetep aja keok 😂 gw tau semua tu yg ada di balik layar ini adalah pro anies gw dah paham rekam jejak mereka semua.😂: negative
# INGAT DULU JAMAN SOEHARTO? SEMUA PNS ATAU ANS WAJIB MEMILIH GOLKAR? ELU SEMUA DIAM-DIAM AJA!!!: negative
# Padahal udah sejelas dan senyata ini ketidaknetralan dan kecurangan dalam pilpres 2024 , tapi para pendukungnya masih bilang kalo film dirty vote isinya fitnah semua
#
#
#
# Pak Jusuf kalla pun bilang, di film dirty vote baru 20% persen doang  kecurangan2 yang dibeberkan
#
# Parah.
# Respect buat kalian yang membuat film ini  ,
# Indonesia butuh orang-orang yang cerdas dan berani seperti kalian 👍👍👍
#
# 2029 kalo umur masih sampe, badan masih sehat,  fix, saya akan Golput, karna memang sepertinya politik Indonesia udah benar-benar gak bisa saya percaya lagi
# Rusak
#
#
# Plis lanjut part 2 🙏🙏🙏: positive
# Udah bukan dirty vote ini mah udah kagak ada vote vote nya 😂😂😂: neutral
# Yang terpenting adalah warga negara kita masih aman dan ekonomi  masih stabil..
# Kita positif sja dalam berfikir... Intinya semua yg di lakukan presiden tujuannya untuk rakyat. Bukan untuk diri sendiri...
# Ini bentuk demo yg paling keren,kreatif,sopan dan damai....👍👍: positive
# haha: positive
# Pendapat prof Ysril dan prof margarito  llebih masuk di  nalar saya bos...: neutral
# Ini pendapat kalian saja bos: negative
# Pendapat 3 orang ini sama sekali  tdk menarik: neutral
# Sudah begini detainya data,tapi sayang tidak bisa di proses.: neutral
# Kepo gw Bru ksini😂: neutral
# Hidup Berakal MATI Beriman: positive
# Cape cape bikin film ini ttep aja KALAH: negative
# Pantes kenceng banget teriak bansos nya,ngeluarin film dirty vote di masa tenang berbalut akademisi,pakar hukum tatanegara  ternyata anda dusta semua: positive
# Ternyata feri amsari ada di barisan tim hukum amin,yang katanya netral dusta2: neutral
# Sinetron hoak: negative
# Gak perlu bikin film kyak gini..rakyat sekarang sudah cerdas..
# Makanya kpu adakan debat capres itu gunanya biar tau visi misi..
# 01 03 bukan visi misi malah saling serang dan saling menghakimi 02..
# Disitulah rakyat mulai tau mana pemimpin yg benar...
# Jadi film gak bermutu kayak gini gak begitu punya pengaruh besar buat narik suara rakyat..dan tidak semua rakyat mau liat ini,.dasar kalian orang² cerdas tp bodoh tidak bisa membaca situasi rakyat sekarang: negative
# ini bukan film . . . Ini cuma pihak2 yang tidak pro dengan pemerintahan saja yang mau menjatuhkan dengan mengait2kan dengan pemilu. Ini drama pembodohan: negative
# KALAH YA KALAHH AJA KO00NNNTTOOLLLL: negative
# Woy prabowo menang😂😂😂❤❤❤❤: negative
# Film sampah😂😂😂engga ngefek tuh di pemilu😂😂😂: neutral
# Film ini sengaja dibuat dan di upload karena mereka sejak awal sudah tahu bakalan kalah dari 02..makanya di buat seperti ini untuk menyebarkan isu seolah2 pemilu ini curang..kalau memang curang ya buktikan jangan asal ngomong aja..anda bilang kepala desa dan kepala daerah di tekan..emang bisa presiden menekan semua kepala daerah..kepala daerah itu jabatan politik tidak bisa presiden semena2 memecat kepala daerah dan rata2 diusung oleh parpol..jadi kalau pun ada tekanan dari kepala daerah tidak mungkin tekanan itu cuman memihak ke 02 pasti juga ada yang memihak ke 01 dan 03..kepala daerah pun tidak sepenuhnya bisa menekan  masyarakat..kalau anda mau bilang kepala desa..kepala desa itu juga dipilih oleh rakyat tidak mungkin bisa 100 persen mau menekan rakyat..kalai memang ada kepala desa ataupun kepala daerah yang di tekan..buktikan siapa orangnya hadirkan..biar tidak selalu memberikan berita2 yang selalu fitnah..kami rakyat muak dengan ini semua..sudah kalau kalah ya kalah aja..kalau memang tidak mau kalah jangan bertarung..itu aja..atau memang sengaja cari viewers ya biar banyak yg nonton film ini..?: negative
# Dirty vote, sexy killer, ini film2 yg dibuat oleh orang2 yg gak suka sama pemerintah pak jokowi.
# Tp nyatanya di bawah rakyat kecil sangat mencintai pak jokowi. ❤: positive
# Tahun 2019 ada sexy killer, gak ngaruh sama rakyat.
# Rakyat itu klo mau memilih pemimpin pasti pada berdoa dulu, dan hasil dari do'a kita bersama 02 menang.
# Pemilih 01 & 02 jg pasti berdoa utk supaya pemimpin yg terpilih itu yg terbaik, dan doanya dikabulkan 02 ditakdirkan menang itu jg berkat do'a tulus rakyat Indonesia.: positive
# Aqu emak2 miris liat negara Indonesia saat ini. Kalau masih byk mahasiswa yg acuh dan gak peduli dg politik di Indonesia percayalah kalian akan tertinggal. Yg masih bilang siapapun presidennya gak ngaruh dg kehidupan kita, coba anda rasakan sendiri sulitnya ekonomi dan lapangan pekerjaan Krn kebijakan politik semena2: negative
# Susah susah buat ni film dirty vote... Ehhh nyungsep 16%... Lowbet ya😂.. Mampus: negative
# Sangat mendidik ...seharusnya kita lebih berani ..soalnya demokrasi indonesi udah di acak2 oleh segelintir manusia....ini udah melebihi rezim Suharto....(mengerikan lebih mengerikan yg ini)....: positive
# Mau dikasi 100rb,200rb,Sembako atau apapun.
# Penentuan pemilih hanya di bilik suara.
# Yang tau yg dipilih hanya diri sendiri.
#
# Hasilnya setelah dikumpulkan.
# 😂❤❤🎉: neutral
# Alhamdulillah adanya film ini malah memenangkan Paslon 02: positive
# Film taekkk😂: neutral
# Dengan film ini salut dan apresiasi cermat sekali untuk edukasi politik terus terang banyak masyarakat yg kurang peduli tentang hal ini . Kita siap menuju perubahan .: positive
# Simpe saja kawan karna pak jokowi sudah tahu isinya partai itu ,sudah jelas dia memihak kepada yg paling benar ,karna beliau sudah hatam kelakuan partainya#gooooo 02: negative
# Hadeeeh. Kalo rakyat yg milih gimana itu??: negative
# Jokowi vs everybody 😅😅😅.. untuk para pembenci jokowi semoga sehat dan semoga sllu dalam lindungan ALLAH .. untuk pak jokowi anda memang the best bisa bikin mereka2 pembenci jadi kocar kacir 😂😂: positive
# 🎉mantap: neutral
# Kok 02 saja yg sering di sorot: positive
# Hebat moderator2 kt ini menjelaskannya dan bisa sabar melihat biadab2 itu melakukan kejahatannya demi jabatan dn uang .. sy sj yg melihatnya panas emosi .. smga sj ALLAAH cpt memberi azab buat usman dkk nya .. atas penderitaan rakyat .. aamiin YRA: negative
# Sayang nya gak laku wkkkkk😂: neutral
# Dari semua ini situasi seperti ini akan terus terjadi sampai kapan pun.
# Karna watak rakyat indonesia sudah terbiasa terjajah dri dlu dan sudah biasa di sogok dri zaman dahulu.
# Jdi kita harus faham dri sekarang.
# Karna demokrasi dan kemerdekaan itu tidak pernah ada.: negative
# Kenapa melupakan pengadilan yg maha adil? Segera bentuk istigosah nasinal!, insya Alloh beres: positive
# Kalian adalah sekumpulan orang yg sakit hati dan penuh kebencian. Posisi anda tidak netral jadi anda tidak memiliki kapasitas untuk menilai curang dan menilai demokrasi di negara ini mengalami kemerosotan. Kalian adalah kelompok pencundang yg di mana jagoan kalian kalah dalam kontetasi pemilu. Berjiwa kesatria lah jangan mengajari dan ngedoktrin khalayak banyak dengan kebencian dan ketidak sukaan.: negative
# Presentase gagal😂: neutral
# Sok idealis yakin tuh gsk ada byaran dari partai tertentu sdar bung fery bangun cari duit jangan saling adu domba biar berkah  air beriak tanda tak dalam ya ini mereka" Yg ada di film ini
# Allahu akbar hukum mereka yg dzolim ya Allah: neutral
# Pejabat punya potensi untuk memenangkan Pilpres. Tapi jangan Langsung membuat kesimpulan bahwa Rakyat memilih karena immbauan / instruksi dari Pejabat. Terbukti bahwa Pilkada DKI yg menang adalah Anies , meski Ahok didukung Jokowi. Pilpres 24 di Aceh, yg menang adalah AMIN. Jadi, SUARA RAKYAT ITU TIDAK SEMUANYA MEMILIH ATAS IMBAUAN, TEKANAN DAN PAKSAAN PEJABAT. Jangan membuat simplikasi yg mudah TENTANG RAKYAT.
# Jadi jangan merendahkan RAKYAT. Rakyat sudah bisa memilih  apa yg menjadi pilihannya. Berbagai issue kecurangan, mulai MK, BANSOS, PENUNJUKAN PLT, telah diviralkan di berbagai media juga sudah diketahui Rakyat. Tapi apa hasil PEMILU PILPRES? Kenapa kita tidak melihat FAKTA nya????? Kalau kemudian disimpulkan ada kecurangan yg masif, terstruktur  dan sistematis, ya tinggal dibuktikan. Ga usah repot untuk dianalisis. Sekali lagi, JANGAN MERENDAHKAN SUARA RAKYAT. Kalau anda mendukung salah satu capres, karena  berbagai informasi dari berbagai dari media ( termasuk spt di film ini ), ya monggo pilih capres pilihan anda.
# Semua informasi yg anda peroleh persis sama dg yg saya terima, tapi pilihan Capres kita berbeda, apakah saya salah dan anda yang benar??? Jangan memonopoli pilihan.
# Kalau soal kecurangan dalam PEMILU, dari sejak jaman MAJAPAHIT, pemilu, pilkades pilkada, sudah ada kecurangan.
# Para akademisi spt anda ini, harusnya bisa melihat secara lebih komprehensif  bagaimana meminimalisir kecurangan dalam pemilu, apalagi anda ahli Tata Negara, jangan mensimplifikasi masalah. Sistim Ketata negaraan kita menang masih perlu diperbaiki. Partai kita perlu di reformasi, Ketua2 PARTAI nya belum pantas menjadi pemimpin Partai. Persyaratan menjadi Presiden, menteri, Gubernur , Bupati / eksekutif lainnya, Anggota DPR, Hakim, Jaksa dsb terlalu mudah dan perlu direformasi.  Perlu lolos test tentang apa itu Pancasila UUD 45, wawasan kebangsaan Nusantara sistem pemerintahan, geopolitik dan geo ekonomi, korupsi, toleransi , juga syarat pendidikan formalnya. Menurut saya, terjadinya semua carut marut bernegara ini adalah ketidak kompentennya para elit sendiri, sehingga menghasilkan konstitusi spt ini. Semua mengatas namakan RAKYAT. RAKYAT YANG MANA. Bukankah semua ini sebagian  besar kesalahan ELIT?? Dalam pemilu ini, hampir semua Partai, Caleg, Capres melakukan kecurangan dalam versi masing2.
# Buatlah sistim dimana reqruitment para pemimpin harus diperketat. Tidak spt sekarang ini, semua bisa jadi anggota DPR, BUPATI , GUBERNUR dsb. asal punya uang. Sistem yg ada tidak sehat.
# -----
# Mas, mbak, kalau saya konglomerat yg jaringan bisnis yg luas dan punya tenaga kerja lebih dari 50 ribu orang dan cukup sekali ngomong di perusahaan untuk memilih paslon tertentu apakah ga akan diikuti oleh semua karywannya? Apa itu kecurangan? Bayangkan kalau ada 100 konglomerat melakukan itu? Jawabannya Rakyat bisa nurut dg Konglomerat dan bisa tidak NURUTIN kemauan  bossnya.
# ---&
# Sekali lagi, RAKYAT sudah bebas menentukan pilihannya. Era sekarang sudah demikian terbuka. Informasi yg diterima oleh Rakyat dari berbagai media sudah hampir sama. Jangan menyimpulkan bahwa kalau sudah nonton film anda ini terus memilih Capres yg sama. Buktinya saya. Meski sejak 2012 sampai sekarang  ga senang JKW, memilih PRABOWO. ini karena dari ketiga calon yg ada ( semuanya belum memiliki kriteria yg pas ), PRABOWO yg terbaik.: positive
# kalian yang mengotori hukum.. siap" dgn hukum TUHAN YME. bodoh sekali kalian memilih hidup yang hanya paling lama 90thn, dari pada hidup kekal di atas sana. kalian lupa bahwa TUHAN YME maha melihat dan mendengar. siap" menjawab para malaikat di alam kubur: negative
# Begitu ngeri y elit elit y kita  begitu busuk y innalilahi wa innailaihi Raji'un 😢: negative
# Masyarakat : ooohhhh jadi jokowi dan prabowo jadi satu... pilih prabowo aja deh ada jokowinya😂😂😂: positive
# Bung tolong lanjutkan untuk DIRTY VOTE PART 2, karena masih banyak lagi yang harus kamiketahui perkemabngan Pemilu Indonesia 2024. Terima kasih. Ditunggu yaa: positive
# Seandainya presiden mendukung paslon 01 / 03, apakah film dirty vote akan tetap di buat ?
# Kurasa tidak sih 🥱: neutral
# Trims.. utk team pembuat konten ini.. kalian menyadarkan bnyk org termasik saya.. tp apaboleh buat.. setidak nya ini pembelajran kedepan..: negative
# Balik lagi ni gua, di akun kocak. Udah selesai ni pemilu, part 2nya ditunggu biar suasana indonesia makin kocak. Hidup di negara ini saya merasa senang, terhibur sekali dg kekocakan kekocakan anda 😂: positive
# Semoga ke 3 tokoh ini baik baik saja. Aamiin. Mudah mudah an ke 3 tokoh ini tdk seperti munir. Dalam perkataan nya dalam berbagai media.. Merekasudah terlalu banyak tau tntg bobrok nya pemerintah an yg dikuasai oleh elit politik: positive
# Mantap: positive
# Tak perlu pintar untuk melakukan kecurangan, cukup mengesampingkan rasa malu: positive
# Habis ini semiga lanjut menjadi grup musik TRIO: positive
# Mbak be fitri hidungnya mancung😊: positive
# coba bikin film president yang di rendah kan oleh kepala kader nya apa kalian lupa ?: negative
# Mentang2 sdg berkuasa lalu berbuat sesuka hati.ithulah contoh dari pemimpin kita yg katanya sederhana.aslinya jokowi ogah berbuat adil.: negative
# WKWKWKWKWKWKWK LAWAK DEKKKK: positive
# 💪: neutral
# apa mau lihat video  pks, pdip dan pkb bagi bagi bansos jelang pencoblosan,  apa mau di angket juga😂: positive
# Sejarah mencatat bahwa pernah ada presiden RI yg culas berpolirik tak beretika tak bermoral dan tidak   tahu malu bernama si jokowidodo: neutral
# Gua Suka banget nonton film ini tapi gua pilihnya tetap 02: positive
# Mastermind nya akn dipertanggungjawabkan dunia akhirat dan org2 yg terlibat mau bekerja sama ikut arahan si master of conflict
#
#
# bkn aproximasi tapi hal-hal prognitis yg dilakukan.
#
# TEGAR 'Teu Gableug Kaera': positive
# Hilang dong di pencarian: neutral
# Film jancuk bikin onar banyak orang juga bikin pecah NKRI, itu yg 1 nya ngapain tidur kalau sidang belum selsai , heran gw junjungannya mardigu juga ni: negative
# Pala bapak kau curang: negative
# Alhamdulillah saya tidak membenci pemerintahan yang sah. Karena sudah ada di hadist nabi kita tidak boleh membenci pemerintahan yang sah...: positive
# 9 juta penonton video ini hanya tau kok bahwa ini rancangan video untuk menjatuhkan 03&02 😂: negative
# Katanya ahli tapi Tendensinya terlalu kentara😂😂😂😂: positive
# Kalau mau bahas kecurangan itu menyeluruh bos, sekalian paslon yg d usung NASDEM PKS: negative
# Film bukanya mempersatukan bangsa malah memecah belah: neutral
# Orang² yg bicara d video ini tengah mencari jalan untuk d gaet pemerintah. Info posisi/jabatan mazzeh😂: negative
# Film apa nih wkwkkwk: neutral
# Jujur ini gw baru banget masuk ksini tpi gk gw tonton, cuma langsung gw baca komennya, gw perhatiin komennya ini masih antar pendung 01 dan 03, dari sekian view 9 jutaan cuma ada komen 74 ribu, dan gw yakin dari pendukung 02 mungkin banyak yg nonton disini tpi mereka lebih memilih no komen, karna udah tau dari aktor film ini timses nya 01 dan 03 yg lagi kerja kelompok ...
#
# Silahkan 01 dan 03 yg mau ikut komen ngehujat gw dsini, ini cuma unek unek gw, gw cuma gk suka seorang aktor yg bilang ini netral tpi isinya tai semua..
#
# Apakah dsini ada yg pendukung 02, coba komen apa faedahnya ini film, jujur gw bener bener gk nonton, gw cuma nonton di potongan tiktok beberapa detik: positive
# ...
# Pesan yang dapet kita ambil dari film ini adalah
# jika kamu menyampaikan kebenaran maka kamu akan menemukan 2 reaksi yang berbeda
# -orang yang cerdas akan merenung
# -orang yang bodoh akan tersinggung: negative
# yah diliat dari komentar orang² presiden sekarang harus "suci" gak boleh punya keburukan sama sekali. "presiden wajib spek nabi" seakan sekali dia berbuat kesalahan di masa lalu gak akan pernah dimaafkan
#
# miris banget: negative
# Terimakasih team Dirty Vote karena telah memberikan fakta-fakta yang luar biasa👍 Dukung perubahan lebih baik.: positive
# Dunia tak sepolos itu kawan: neutral
# Sudah lama sy bertanya-tanya kok sekarang banyak sekali penunjukkan walikota, bupati...ada apa?..kenapa?..ternyata ini jawabannya..Indonesia  benar2 lagi sakit... ...terimakasih: negative
# INGAT GAES.... HIDUP ENAK BELUM TENTU MATI NYA JUGA ENAK..
# DI DUNIA LU BOLEH DI GENDONG PAMAN, KEBAL HUKUM,, DI AKHIRAT BELOM TENTU LU BISA DI GENDONG PAMAN KE SURGA DAN KEBAL DARI SIKSA NERAKA: positive
# engga mikirin rakyat, sakit jiwa banget banget 02 emang. untung 03 selalu di hati: positive
# Tetep 02: positive
# Stelah liat film ini, ahirnya sya pilih prabowo gibran🎉😎: negative
# Keren: positive
# Rasanya semakin kecewa dengan Pak Jokowi 😕: negative
# Menuju indonesia sehat akal ❤: positive
# 4 jari kerja kelompok ?😂: neutral
# Terima kasih team dirty vote...: positive
# Secara ngga langsung ini mgedukung anies ya ?: negative
# Bismillah 🙏: positive
# Kalau sudah seberani ini berarti sudah separah itu.: negative
# Aku curiga, HTI ada d balik semua ini: neutral
# Terimakasih atas ilmunya kepada kami yang buta akan permainan politik di negeri kami: positive
# Nanges gak sih.. 😢 hati saya sbg wni merasa tersakiti: neutral
# MK itu artinya adalah MEMBANTU KEPONAKAN. mendingan 03 aja deh, 02 udah ngecewain banget.: negative
# memlih 1,2, atau 3 memiliki resiko nya masing - masing.. Jadi untuk para pemilih, ketahuilah resiko itu, sadar dengan resiko itu, dan bertanggung jawablah dengan resiko yang sudah anda pilih... Yang terakhir.. Tolong berhentilah menitik beratkan seluruh kesalahan di pemerintah, karena yang bertanggung jawab atas kekuasaan mereka adalah suara anda: negative
# film ini ngasih tau fakta gimana kalau aturan bahkan undang-undang bisa diotak-atik yang penting 02 menang. SAMPAH banget 02.: negative
# Siapa yg d serang, dia yg akan menang: neutral
# ada indikasi transaksi dan konstitusi yang bikin gua makin yakin buat ENGGA NYOBLOS 02. mending 03 ke mana-mana: negative
# pengalaman pribadi dari 3 narsum ini, bikin mata gua terbuka buat nyobolos 03 aja dari pada paslon yang lain.: negative
# film yang bagus. bikin sadar kalau 02 emang ngaco.: negative
# makasih udah mau ngasih tau fakta dibalik pemilu tahun ini mas dan mba dirty vote. kalian ngeyakinin gue buat milih ganjar-mahfud aja daripada 02.: negative
# Besok prbowo pasti menang.: neutral
# Terima kasih banyak kepada beliau semua yg sdh berjuang dan berani untuk karya yg sangat penting ini❤: positive
# tadinya yakin all in 02, pas film ini keluar, bismillah ALL IN 03.: positive
# Semoga setelah menonton film ini pandangan setiap rakyat indonesia lebih terbuka dengan masif nya kecurangan ini... membuka mata dan pikiran bahwa kita yang bs mengubah ini semua krn kita rakyat. Mari berdoa bersama untuk keamanan negara kita dari pimpinan zalim.. hanya allah sebaik baiknya penolong..
#
#
# Apresiasi gimana tim ahli dan crew yg terlibat dalam pembuatan movie ini.. terimakasih: positive
# catatan penting buat pendukung 02. noh paslon kalian banyak masalah. mending juga geser ke 03. lebih jelas dan berpengalaman.: negative
# Syukurlah kukira hilang: neutral
# Laporkan sesuai uu nomor 7 tahun 2017 tentang pemilu pasal 287 ayat 5: neutral
# abis nonton film ini, mending kubur aja deh mimpi buat menang satu putaran. 03 siap ambil suara 02 nih.: negative
# Nonton kali kedua, biar lebih paham: negative
# Bismillah doa terbaik untuk negeri ini.: positive
# ini mah secara tidak langsung memojokkan nomer 2: positive
# 7.6jt: neutral
# 02 ini terlalu kontradiktif dengan pendukungnya. jadi mendingan 03 ke mana-mana.: negative
# Bodohnya orang orang yg mendukung Prabowo.... Sudah dengar ucapan Agung Gumelar dimana tim mawar Prabowo membantai aktivis 98 tapi tetap di dukung.... Sudah tau media asing menyoroti korupsi pesawat bekas oleh Prabowo tapi tetap didukung... Sudah tau program food estate merusak alam di Kalimantan tapi tetap mau milih... Tau pajak rakyat kecil mau dinaikkan tapi kok didukung....: neutral
# Up: neutral
# bismillah yakin, paslon 03 yang terbaik.: negative
# kata nya pake data kok Lo yang kemana politik identitas dan 31k suara sdah di coblos ada gak?: negative
# Ngeriii juga pak de Owi . . 🤮: negative
# Ya Allah YA Robbi..berikanlah negara ini pemimpin yang amanah dan mewakili suara rakyat: negative
# semoga beliau² 3 tokoh yg bicara di awal film selalu di jaga Allah SWT: neutral
# Untuk Generasi Muda INDONESIA, bandingkan baik-baik pilihan kamu, karena Indonesia yang akan datang adalah milik kalian, bukan milik 1 partai, atau bahkan bukan milik 1 keluarga. Sekali mereka merasa bisa merusak demokrasi Indonesia, mereka akan melakukannya lagi... dan lagi... untuk memutusnya, KITA membutuhkan KEMENANGAN MUTLAK yang tak akan bisa dicurangi... Indonesia itu ONE man, ONE vote... jadi walaupun 1 suaramu, akan ikut menentukan masa depanmu... masa depan bangsa ini... Bangsa INDONESIA...: neutral
# 7 juta views menyatakan anti 02, asal bukan prabowo gibran: negative
# Memanipulasi data atas arahan atasan: neutral
# Gua nengok aja,yg penting 02😂😂: negative
# Thank you for this amazing documentary. Good explanation and easy to learn.: positive
# Dirty Vote semoga semuanya pada tersadarkan: positive
# Parah sih kok ga masuk tranding di Yt: negative
# Sekarang begini kalian semua sekarang menikmati hasil kerja keras pemerintahan saat ini. Entah itu jalan bansos ataupun kebebasan berbicara selama ini. Akan kah lebih bagus bila mana kalian sedikit berterima kasih atas semua yang kita rasakan selama ini sodaraku. Bukan malah mecocoklogi kan semua yang terjadi sekarang ini. Dan seakan akan untuk menjatuh kan peluang Indonesia emas 2045: negative
# 02 menang 1 putaran: positive
# Banyak yg gatau background orang” dari ini dan isi” dari vidio ini sumbernya dari manaa🤣🤣 #dislike: negative
# Scene terakhir bikin banyak ngelus dada. Pelajarannya, manusia ga ada apa-apanya, kalau dia baik tapi ga benar, ga ada nilainya, di tinggal begitu saja tanpa tapi tanpa nanti. Kalau udah ditinggal manusia, kemana lagi kita harus bergantung? Mumpung masih diberi kesempatan hidup yang maha esa, banyak banyak intropeksi diri.. 😭: positive
# Sebenernya hal kaya gini ituu masyarakat udh tauuu...
# Pasti ada something di belakang layar..
# Tapi sebagai rakyat yg ga punya wewenang hanya cukup tau aja..
# Keren sih bisa klipping begini jd film..: neutral
# Bawaslu harus di proses hukum: neutral
# 31 surat suara yg udah dcobloa kok gak dibahas?
# Trus politik agama yang kampanye dmesjid kok jg gak dibahas?: positive
# Mengapa vidio ini tidak masuk trending 😢 apakah yt bisa diatur oleh manusia 😢😢: negative
# ❤😂🎉: neutral
# Gmna mau percaya, yg katanya netral tapi aktornya dari pks sama pdip wkwkk
# Trus diakhiri dengan salam 4 jari pula... 😶: negative
# #PRAGI: neutral
# #GAMA: neutral
# Ga ngaruh ttp 02: positive
# Like: 418rb
# Dislike: 17rb: neutral
# Terima kasih banyak karena telah menyadarkan kami. Saya tidak pernah menyangka bahwa sehancur itu hukum & demokrasi di Indonesia ini.: negative
# Cerdasss,,,: neutral
# ternyata banyak banget keturunan LONDO IRENG pengkhianat bangsa....
# keturunan Pitung kebanyakan sudah pada dipiting.
# jalan terakhir hanya berharap kepadaNya.
# harusnya itu jalan utama, tapi sudahlah...
# maksiat dimana2: negative
# Rezim paling bobrok mentalnya sepanjang sejarah NKRI...muka Gedeg dableg permanen sudah hilang akal sehatnya hilang rasa malunya sebagai manusia .....ga tau masih jadi manusia apa sudah berubah bukan jadi manusia .: neutral
# Pendukung 02 dikasih fakta malah dibilang fitnah.. Kam tolol😊: negative
# Saya di akhirat nanti akan menjadi saksi, betapa culas dan tamaknya manusia2 yg diberi kekuasaan di negri ini.: positive
# Apakah warga konoha mau nonton film wawasan keilmuwan? Apalagi ini satu jam lebih 😢: neutral
# Senjata pamungkas, setelah segala cara gagal semua....
# Grand design mendelegitimasi pemilu....untuk menolak hasil pemilu....
# Para NGO yang membuat ini di danai oleh siapa....? Kebanyakan mereka di danai asing....siapa capres yang antek asing...? Capres yang keliling eropa kemaren 😅
# Dirty Vote comes from who has Dirty Mind...: negative
# Jelas dong anaknya masa ga didukung😂: neutral
# Kalau memang film ini netral kenapa pembukaannya yg di tampilkan jokowi dan paslon 02 kenapa gak di mulai dari 01 sampek 03🤔🤔: negative
# Rakyat harus cerdas: positive
# Setelah melihat film ini, gak jadi milih 02: positive
# Alhamdulillah Terbuka Mata saya sudah Kebenaran dan Keburukan yang Terjadi: positive
# Sampai susah banget mau lanjut nonton film ini, tiba2 ilang dan dicari susah, untung ada yg post lagi linknya 😂
# Yang waras kudunya ngerti kenapa bisa mendadak susah dicari ini film padahal ditonton jutaan kali.: positive
# Panjang umur kebenaran: positive
# Kenapa pembukaannya kok bukan anies?🤔🤔🤔🤔🤔: negative
# hidup 02: positive
# *reminder ya,plis nnton sbg rakyat bkn penggemar paslon tertentu. Buka mata hati kalian*: neutral
# Alhamdulillah saya awalnya ikut ikut teman milih 02 gatau nya isi nya orang jahat di 02: positive
# Saya dan keluarga memilih untuk melawan kecurangan Jokowi dalam mengangkat anaknya sebagai cawapres dengan cara memilih GANJAR MAHFUD sebagai Presiden dan Wakil Presiden 2024 - 2025..: positive
# Luar biasa, tindakan yg sangat besar resikonya, semoga semuanya dilindungi oleh Allah SWT: positive
# Tetap 02😂😂😂😂😂😂😂😂😂: negative
# tontonlah film dokumenter ini bukan sebagai pemilih paslon sekian tapi sebagai rakyat.: neutral
# The real mental culas dan ga punya malu.: neutral
# BAWASLU kerjaan kalian ngapain aja?: negative
# Sejahat itu ternyata dibalik layar negara😭.: negative
# Salam 4 jari gak tuh wkwk 1+3. Dibuat seolah netral tp gak netral. Bu iriana 2 jari dibahas. Ma'aruf amin yang cawapres pose 3 jari gak dimasukin tuh. Kecurangan surat suara di taiwan gk dibahas. Kecurangan di boyolali harus menangin 03 gak dibahas: neutral
# Mencerdaskan kehidupan bangsa....: neutral
# ini dari 01 takut kalah: negative
# Terimakasih kepada Bpk Prabowo Subianto telah bersedia mencalonkan presiden lagi dan selamat atas kemenanganya: positive
# Jika Allah sudah berkehendak Pak Anies yang menang maka tidak akan berguna semua kecurangan paslon lain: negative
# takut kalah wkwk: negative
# Jauh lebih mengerikan daripada film horor: negative
# Nitip jejak  👣: positive
# lm jelek: negative
# Zulhas penistaan agama harus di proses hukum: neutral
# filem jelek menjelek jelek kan 02 males nonon nya
# ..rakyat sdh tau broooo: negative
# Menuju demokrasi yang  bersih jujur serta mencerdaskan bangsa, pilih pemimpin yang kompeten serta bisa menjunjung keadilan bagi seluruh Rakyat Indonesia, bukan pilih pemimpin menguntungkan kantong pribadi dari oknum oknum yang berpura2 ....: negative
# FILM PROPAGANDA. SETIAP MENJELANG PEMILU DAN SETELAH PEMILU SELALU MUNCUL FILM-FILM SEPERTI INI: neutral
# Film dokumenter yg berisi fakta Krn berisi kumpulan kliping berita..mantap: positive
# Jadi kalau fakta atau data yg disampaikan terus berhubungan dengan 01 atau 03 itu di tuduh fitnah? kalau fakta data yang dibls dengan fakta data juga lah, jangan beropini yg lain. Lihat apa yg disampaikan jangan siapa yg menyampaikan.: negative
# Orang orang hebat Indonesia... panjang umur kebenaran dan kecerdasan berpikir✊: positive
# Ga punya etika di masa tenang, melakukan hal yang ga punya otak kayak gini: negative
# Gabisa dibuka kecuali pake link
#
# Ternyata YouTube SEHARAM ITU UNTUK MEMBELA YANG BERDUIT, ALIAS YOUTUBE GAK PUNYA HARGA DIRI & HANYALAH SAMPAH!!!: negative
# Film yg menambah keyakinan kami untuk tidak memilih Paslon itu, sangat tidak ikhlas, Sudi dan rela rasanya kalo negara ini dikuasai segelintir orang perusak demokrasi dan konstitusi: positive
# Sangat bagus untuk mencerdaskan publik... Salut dengan yang bikin❤❤❤
#  walaupun dia tau apa resiko yg akan terjadi....: positive
# Kirain film netral jiah film menjatuhkan, cape2 koar2 pemilu damai tapi di provokasi kwkwwkwkkwwk: positive
# Landasann haaa landasaan? ;biar lebih fahamm ?  Jangan ngarang kalo mau survei tu keseluruhan jangan kampanye di saat waktu kampanye udh di tutup kelitan banget kalo mau jatuhin orang niat ngasih filem jauh jauh hari biar masyarakat biasa berfikir dan mencari kebenaran bukan waktu mepet pemilu terus but vidio begini sekan mau merubah pikihan rakyat: negative
# Dirty vote kalau beneran besok merubah sudut pandang para Voters , bisa di bilang ini Reformasi 2.0 .... Lets see 14 Februari 2024: neutral
# inshyaAlloh makin yakin pilih anis dan PKS. inshyaAlloh mereka org2 baik, cerdas dan amanah. Paling tdk mereka lbh baik dari yg terburuk.: positive
# 47:30 saking tololnya begituh.: neutral
# Rasanya ingin teriak anjeng kalian semua. Kalian anggap rakyat ini hanya tim hore kalian? sementara kalian cuma berebut kekuasaan dengan cara kotor: negative
# Semoga ini semua akan menjafi sejarah kl seorang Preaiden yg sdh menyalah gunakan jabatannya tdk boleh dibiarkan untuk itu Masy jrs hati2 memilih Partai ini lah akibatnya Partai yg mengusung Jokowi ancuuur benar2 negerinini tumbal partai banteng seharusnya Banteng bertanggung jawab atas kekeliruan yg di lakukan Jokowi Ngeri negwrinini diluar negeri Negara Indobesia sdh tdk ada lg negarq yg disegani korupsi paling tinggi kemiskinan kr sll diberikan bantuan makan dan makan sdg kan pendidikan tdk diperhatikan: negative
# gila gabisa di cari di yutup langsung...: negative
# Negara ini sedang tidak baik² saja. Semoga allah bukakan dan perlihatkan kebenaranannya. Aamiin: positive
# Banyak 02 😂: positive
# Amin 2024 perubahan: positive
# Mau nonton..tapi apakah saya kuat 😢: positive
# Menyesatkan, ga ada adab!!: neutral
# Lebih baik dibodohi orang bodoh daripada dibodohi 3 orang yang pintar membodohi.: negative
# Kyanya masyarakat bodoh di Indonesia di pelihara gak di upgrade, akhirnya meraka gak melek dgn kondisi demokrasi saat ini, setelah dibodohi sumber daya alam kita di Indonesia di gerus sama org2 yg berkuasa, krna masyarakat gampang dibodohi mereka gak akan protes akan hal itu Nntinya
# #savedemokrasindonesia: positive
# Film apa gk paham: neutral
# Film bodoh mending di take down aja!!!: negative
# Filem ini adalah kamu yv stres.: neutral
# Hallaaaahhhhh udaaaa jelekkkinnnnnn oranggggg gilaaaaaaa g sihhhh!!!! G Bahas semua Paslon,.. 😅😅😅: negative
# Terima kasih Bapak/ibu dan yg terlibat didalam ny.. Sudah rela menjadi martir atas segala resiko... Semoga selalu dalam lindungan Allah swt..: positive
# Jadi paham..: negative
# Gila yang dibenci jokowi yang di sudutin dan di hina prabowo gibran, bener kata orang kalo udah iri hati kalo udah kena penyakit hati segala  apapun akan di lakuin untuk menjatuhkan seseorang tersebut😢 najis dah: negative
# Orang sipil perusak demokrasi: neutral
# Terimakasih untuk para guru besar katanya seperti kuliah, saya jadi merasa jadi mahasiswa selama 2 jam, dari sebelum ada film saya sudah tau sih tapi film ini membenarkan pikiran saya, semenjak ada pemuja penguasa saya paham klo negeri ini sedang tidak baik2 saja, serang sana sini yang seharusnya rakyat itu bersatu menilai kebijakan penguasa mengkritik bila salah, bukan pasang badan untuk penguasa meneriaki sodara sendiri: negative
# GILA SIH SEMUA UDAH DIPREPARE 😅😅: negative
# 02 parah bangettt 😱😱😱: positive
# Zulhas menistakan sholat, awas Pak masuk neraka: neutral
# Panjang umur untuk hal-hal baik 🌻: positive
# Sudah ada laporan masuk, kuatkan mental bruh kami selalu kawal: neutral
# 1: neutral
# Anak presiden nyalon jd cawapres saat bapaknya masih presiden itu sudah curang. Apalagi sampe mendanai kampanyenya, jajaran pejabatnya ikut kampanye. Sedangkan pns nya hrs netral. Kan aneh: neutral
# Y: neutral
# Terima kasih Rakyat bersama kalian .: positive
# gilaaaaaakk serem bat: neutral
